# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="10"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 1</b></center>
#     <center><b><h1>*****</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World”

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### 02) WAP to print addition of two numbers with and without using input().

# %%
print(10+20)
n1=int(input("Enter your first number:"))
n2=int(input("Enter your secound Number:"))
print(n1+n2)
# Out:
# 30
# Enter your first number: 10
# Enter your secound Number: 50
# 60

# %% [markdown]
# ### 03) WAP to check the type of the variable.

# %%
n=12
s='india'
type(n)
# type(s)
# Out:
# int

# %% [markdown]
# ### 04) WAP to calculate simple interest.

# %%
amount=int(input("Enter your amount:"))
i=int(input("Enter your interest rate:"))
m=int(input("Enter total months:"))
print((amount * i * m)/100)
# Out:
# Enter your amount: 10000
# Enter your interest rate: 10
# Enter total months: 12
# 12000.0

# %% [markdown]
# ### 05) WAP to calculate area and perimeter of a circle.

# %%
n=int(input("Enter radius:"))
print(f"Area of circle:{3.21*n*n}")
print(f"perimeter of circle:{2*3.21*n}")
# Out:
# Enter radius: 5
# Area of circle:80.25
# perimeter of circle:32.1

# %% [markdown]
# ### 06) WAP to calculate area of a triangle.

# %%
b=int(input("Enter your number:"))
h=int(input("Enter yoour number:"))
print(f"area of a triangle:{0.5*b*h}")
# Out:
# Enter your number: 10
# Enter yoour number: 20
# area of a triangle:100.0

# %% [markdown]
# ### 07) WAP to compute quotient and remainder.

# %%
n=int(input("Entre your number:"))
d=int(input("Enter division number:"))
print(f"quotient is:{n/d}")
print(f"remainder is:{n%d}")
# Out:
# Entre your number: 10
# Enter division number: 2
# quotient is:5.0
# remainder is:0

# %% [markdown]
# ### 08) WAP to convert degree into Fahrenheit and vice versa.

# %%
c=int(input("Enter degree:"))
print(f"fahrenheit is:{(c * 9/5) + 32}")
f=int(input("Enter your fahrenheit:"))
print(f"degree is:{(f - 32) * 5/9}")
# Out:
# Enter degree: 5
# fahrenheit is:41.0
# Enter your fahrenheit: 41
# degree is:5.0

# %% [markdown]
# ### 09) WAP to find the distance between two points in 2-D space.

# %%
x1=int(input("Enter x1:"))
y1=int(input("Enter y1:"))
x2=int(input("Enter x2:"))
y2=int(input("Enter y2:"))
print(((x2 - x1)**2 +(y2 - y1)**2)**0.5)
# Out:
# Enter x1: 10
# Enter y1: 2
# Enter x2: 3
# Enter y2: 4
# 7.280109889280518

# %% [markdown]
# ### 10) WAP to print sum of n natural numbers.

# %%
n=int(input("Enter choice number from natural no.:"))
sum=0
for i in range(1,n+1,1):
    sum=sum+i
print(sum)
# Out:
# Enter choice number from natural no.: 5
# 15

# %% [markdown]
# ### 11) WAP to print sum of square of n natural numbers.

# %%
n=int(input("Enter choice number from natural no.:"))
sum=0
for i in range(1,n+1,1):
    sum=sum+(i*i)
print(sum)
# Out:
# Enter choice number from natural no.: 2
# 5

# %% [markdown]
# ### 12) WAP to concate the first and last name of the student.

# %%
first=input("Enter first name:")
last=input("Enter last name:")
print(first+" "+last)
# Out:
# Enter first name: sahil
# Enter last name: kadivar
# sahilkadivar

# %% [markdown]
# ### 13) WAP to swap two numbers.

# %%
n1=input("Enter your first number:")
n2=input("Enter your secound number:")
temp=n1
n1=n2
n2=temp

print(n1)
print(n2)
# Out:
# Enter your first number: 10
# Enter your secound number: 20
# 20
# 10

# %% [markdown]
# ### 14) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
k=int(input("Enter your distance in kilometer:"))
print(f"kilometers:{k}")
print(f"meters:{k*1000}")
print(f"feets:{k*1000*12*3.28084}")
print(f"inches:{k*1000*12*3.28084*12}")
print(f"centimeter:{k*1000*12*3.28084*12*2.54}")
# Out:
# Enter your distance in kilometer: 1
# kilometers:1
# meters:1000
# feets:39370.08
# inches:472440.96
# centimeter:1200000.0384

# %% [markdown]
# ### 15) WAP to get day, month and year from the user and print the date in the given format: 23-11-2024.

# %%
day=int(input("Enter your day:"))
month=int(input("Enter your month:"))
year=int(input("Enter your years:"))
print(f"{day}-{month}-{year}")
# Out:
# Enter your day: 12
# Enter your month: 2
# Enter your years: 2006
# 12-2-2006
